# %%
#Import library
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
data=pd.read_excel("ecommerce_churn.xlsx",index_col = 0)
data.head(3)
# Out:
#             Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# CustomerID
# 50027           0     8.0         Mobile Phone         3              6.0
# 50028           0     NaN                Phone         3             12.0
# 50029           0    18.0                Phone         1              NaN
#
#            PreferredPaymentMode Gender  HourSpendOnApp  DeviceRegistered  \
# CustomerID
# 50027                  E wallet   Male             3.0                 3
# 50028                  E wallet   Male             2.0                 3
# 50029                Debit Card   Male             2.0                 3
#
#               PreferedOrderCat  SatisfactionScore MaritalStatus  \
# CustomerID
# 50027                  Fashion                  4      Divorced
# 50028       Laptop & Accessory                  3      Divorced
# 50029       Laptop & Accessory                  4       Married
#
#             NumberOfAddress  Complain  OrderIncreaseFromLastYear  CouponUsed  \
# CustomerID
# 50027                     2         0                       13.0         1.0
# 50028                     3         1                       20.0         0.0
# 50029                     9         0                       18.0         1.0
#
#             OrderCount  DaySinceLastOrder  CashbackAmount
# CustomerID
# 50027              1.0                6.0          172.95
# 50028              4.0                5.0          123.06
# 50029              1.0               15.0          123.48

# %%
data.shape
# Out:
# (1896, 19)

# %%
data.columns.values
# Out:
# array(['Churn', 'Tenure', 'PreferredLoginDevice', 'CityTier',
#        'WarehouseToHome', 'PreferredPaymentMode', 'Gender',
#        'HourSpendOnApp', 'DeviceRegistered', 'PreferedOrderCat',
#        'SatisfactionScore', 'MaritalStatus', 'NumberOfAddress',
#        'Complain', 'OrderIncreaseFromLastYear', 'CouponUsed',
#        'OrderCount', 'DaySinceLastOrder', 'CashbackAmount'], dtype=object)

# %%
data.describe()
# Out:
#              Churn       Tenure     CityTier  WarehouseToHome  HourSpendOnApp  \
# count  1896.000000  1739.000000  1896.000000      1744.000000     1766.000000
# mean      0.500000     7.347901     1.719409        15.922018        2.682899
# std       0.500132     8.149302     0.936148         8.498368        0.679286
# min       0.000000     0.000000     1.000000         5.000000        0.000000
# 25%       0.000000     1.000000     1.000000         9.000000        2.000000
# 50%       0.500000     4.000000     1.000000        14.000000        3.000000
# 75%       1.000000    13.000000     3.000000        22.000000        3.000000
# max       1.000000    50.000000     3.000000        36.000000        4.000000
#
#        DeviceRegistered  SatisfactionScore  NumberOfAddress     Complain  \
# count       1896.000000        1896.000000      1896.000000  1896.000000
# mean           3.543776           3.275316         4.088080     0.385549
# std            1.015023           1.269551         2.694888     0.486853
# min            1.000000           1.000000         1.000000     0.000000
# 25%            3.000000           2.000000         2.000000     0.000000
# 50%            3.000000           3.000000         3.000000     0.000000
# 75%            4.000000           4.000000         6.000000     1.000000
# max            6.000000           5.000000        21.000000     1.000000
#
#        OrderIncreaseFromLastYear   CouponUsed   OrderCount  DaySinceLastOrder  \
# count                1855.000000  1817.000000  1837.000000        1812.000000
# mean                   15.391914     1.470556     2.694066           3.786976
# std                     3.695976     1.862077     2.866878           3.540237
# min                    11.000000     0.000000     1.000000           0.000000
# 25%                    12.000000     0.000000     1.000000           1.000000
# 50%                    14.000000     1.000000     2.000000           3.000000
# 75%                    18.000000     2.000000     3.000000           7.000000
# max                    26.000000    16.000000    16.000000          46.000000
#
#        CashbackAmount
# count     1896.000000
# mean       164.907252
# std         44.698011
# min          0.000000
# 25%        132.940000
# 50%        150.870000
# 75%        181.610000
# max        323.590000

# %%
#memvisualisasi persentase Churn pada dataset 
fig = plt.figure() 
ax = fig.add_axes([0,0,1,1]) 
ax.axis('equal') 
labels = ['Yes','No'] 
churn = data.Churn.value_counts() 
ax.pie(churn, labels=labels, autopct='%.0f%%') 
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
#konversi semua variabel tipe non-numerikal ke tipe numerikal  
for column in data.columns:
    if data[column].dtype == np.number: continue
    #terapkan encoding pada tiap variabel non-numerikal
    data[column] = LabelEncoder().fit_transform(data[column])
print(data.describe())
# Out:
#              Churn       Tenure  PreferredLoginDevice     CityTier  \
# count  1896.000000  1739.000000           1896.000000  1896.000000
# mean      0.500000     7.347901              1.000000     0.719409
# std       0.500132     8.149302              0.785085     0.936148
# min       0.000000     0.000000              0.000000     0.000000
# 25%       0.000000     1.000000              0.000000     0.000000
# 50%       0.500000     4.000000              1.000000     0.000000
# 75%       1.000000    13.000000              2.000000     2.000000
# max       1.000000    50.000000              2.000000     2.000000
#
#        WarehouseToHome  PreferredPaymentMode       Gender  HourSpendOnApp  \
# count      1744.000000           1896.000000  1896.000000     1766.000000
# mean         15.922018              3.436709     0.613397        2.682899
# std           8.498368              1.550284     0.487100        0.679286
# min           5.000000              0.000000     0.000000        0.000000
# 25%           9.000000              3.000000     0.000000        2.000000
# 50%          14.000000              4.000000     1.000000        3.000000
# 75%          22.000000              4.000000     1.000000        3.000000
# max          36.000000              6.000000     1.000000        4.000000
#
#        DeviceRegistered  PreferedOrderCat  SatisfactionScore  MaritalStatus  \
# count       1896.000000       1896.000000        1896.000000    1896.000000
# mean           2.543776          2.454641           2.275316       1.137658
# std            1.015023          1.375262           1.269551       0.794795
# min            0.000000          0.000000           0.000000       0.000000
# 25%            2.000000          2.000000           1.000000       0.000000
# 50%            2.000000          2.000000           2.000000       1.000000
# 75%            3.000000          4.000000           3.000000       2.000000
# max            5.000000          5.000000           4.000000       2.000000
#
#        NumberOfAddress     Complain  OrderIncreaseFromLastYear   CouponUsed  \
# count      1896.000000  1896.000000                1855.000000  1817.000000
# mean          3.077004     0.385549                  15.391914     1.470556
# std           2.643333     0.486853                   3.695976     1.862077
# min           0.000000     0.000000                  11.000000     0.000000
# 25%           1.000000     0.000000                  12.000000     0.000000
# 50%           2.000000     0.000000                  14.000000     1.000000
# 75%           5.000000     1.000000                  18.000000     2.000000
# max          13.000000     1.000000                  26.000000    16.000000
#
#         OrderCount  DaySinceLastOrder  CashbackAmount
# count  1837.000000        1812.000000     1896.000000
# mean      2.694066           3.786976      164.907252
# std       2.866878           3.540237       44.698011
# min       1.000000           0.000000        0.000000
# 25%       1.000000           1.000000      132.940000
# 50%       2.000000           3.000000      150.870000
# 75%       3.000000           7.000000      181.610000
# max      16.000000          46.000000      323.590000

# %%
#visualisasikan churn dengan males dan females
sns.countplot(x='Gender', hue='Churn',data = data)

# %%
#visualisasi churn dengan PreferredPaymentMode
sns.countplot(x='PreferredPaymentMode', hue='Churn',data = data)

# %%
data.info
# Out:
# <bound method DataFrame.info of             Churn  Tenure  PreferredLoginDevice  CityTier  WarehouseToHome  \
# CustomerID
# 50027           0     8.0                     1         2              6.0
# 50028           0     NaN                     2         2             12.0
# 50029           0    18.0                     2         0              NaN
# 50030           0     5.0                     0         2             14.0
# 50031           0     2.0                     0         0              6.0
# ...           ...     ...                   ...       ...              ...
# 55599           1     1.0                     0         2             16.0
# 55603           1     1.0                     1         0              8.0
# 55605           1    20.0                     2         0             14.0
# 55613           1    14.0                     0         2              8.0
# 55622           1    14.0                     1         2             35.0
#
#             PreferredPaymentMode  Gender  HourSpendOnApp  DeviceRegistered  \
# CustomerID
# 50027                          5       1             3.0                 2
# 50028                          5       1             2.0                 2
# 50029                          4       1             2.0                 2
# 50030                          5       0             2.0                 2
# 50031                          1       1             2.0                 2
# ...                          ...     ...             ...               ...
# 55599                          5       1             3.0                 3
# 55603                          3       1             3.0                 3
# 55605                          1       1             4.0                 3
# 55613                          4       1             4.0                 3
# 55622                          5       1             3.0                 4
#
#             PreferedOrderCat  SatisfactionScore  MaritalStatus  \
# CustomerID
# 50027                      0                  3              0
# 50028                      2                  2              0
# 50029                      2                  3              1
# 50030                      0                  1              2
# 50031                      2                  2              0
# ...                      ...                ...            ...
# 55599                      4                  4              1
# 55603                      4                  0              1
# 55605                      4                  2              1
# 55613                      2                  2              1
# 55622                      0                  4              1
#
#             NumberOfAddress  Complain  OrderIncreaseFromLastYear  CouponUsed  \
# CustomerID
# 50027                     1         0                       13.0         1.0
# 50028                     2         1                       20.0         0.0
# 50029                     8         0                       18.0         1.0
# 50030                     1         0                       14.0         2.0
# 50031                     1         0                       13.0         0.0
# ...                     ...       ...                        ...         ...
# 55599                     2         0                       20.0         2.0
# 55603                    10         1                       15.0         3.0
# 55605                     9         0                       12.0         7.0
# 55613                     8         0                       13.0         2.0
# 55622                     5         1                       14.0         3.0
#
#             OrderCount  DaySinceLastOrder  CashbackAmount
# CustomerID
# 50027              1.0                6.0          172.95
# 50028              4.0                5.0          123.06
# 50029              1.0               15.0          123.48
# 50030              3.0                7.0          189.98
# 50031              1.0                9.0          143.19
# ...                ...                ...             ...
# 55599              2.0                1.0          142.90
# 55603              3.0                3.0          172.87
# 55605             10.0                9.0          148.39
# 55613              2.0                2.0          192.28
# 55622              NaN                1.0          233.54
#
# [1896 rows x 19 columns]>
